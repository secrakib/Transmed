# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/los-of-stay/LOS/LOS_WEEKS_adm_val.csv
# /kaggle/input/los-of-stay/LOS/LOS_WEEKS_adm_train.csv
# /kaggle/input/los-of-stay/LOS/LOS_WEEKS_adm_test.csv

# %%
train=pd.read_csv('/kaggle/input/los-of-stay/LOS/LOS_WEEKS_adm_train.csv')

# %%
train.drop('id',axis=1,inplace=True)

# %%
train
# Out:
#                                                     text  los_label
# 0      CHIEF COMPLAINT: Decreased responsiveness  Maj...          0
# 1      CHIEF COMPLAINT: Fatigue, wide complex tachyca...          1
# 2      CHIEF COMPLAINT: preop CABG\n\nPRESENT ILLNESS...          2
# 3      CHIEF COMPLAINT: \n\nPRESENT ILLNESS: This is ...          1
# 4      CHIEF COMPLAINT: worsening shortness of breath...          2
# ...                                                  ...        ...
# 30416  CHIEF COMPLAINT: etoh w/d\n\nPRESENT ILLNESS: ...          0
# 30417  CHIEF COMPLAINT: Altered mental status\n\nPRES...          0
# 30418  CHIEF COMPLAINT: Chest Pain\n\nPRESENT ILLNESS...          1
# 30419  CHIEF COMPLAINT: Status epilepticus, sepsis\n\...          3
# 30420  CHIEF COMPLAINT: Chief Complaint: cough Reason...          3
#
# [30421 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    train, train['los_label'], test_size=0.0329, random_state=0,stratify=train['los_label'])
len(x_test)
# Out:
# 1001

# %%
x_test.reset_index(drop=True,inplace=True)

# %%
train.los_label.value_counts(normalize=True)*100
# Out:
# los_label
# 1    36.806811
# 2    30.712337
# 3    19.611453
# 0    12.869399
# Name: proportion, dtype: float64

# %%
x_test.los_label.value_counts(normalize=True)*100
# Out:
# los_label
# 1    36.863137
# 2    30.669331
# 3    19.580420
# 0    12.887113
# Name: proportion, dtype: float64

# %%
x_test.reset_index(drop=True,inplace=True)

# %%
sayed_bhai=x_test[:340]
monmoy_bhai=x_test[340:680]
rakib=x_test[680:]

# %%
print(len(sayed_bhai))
print(len(monmoy_bhai))
print(len(rakib))
# Out:
# 340
# 340
# 321

# %%
sayed_bhai.to_csv('Sayed_bhai_0:340.csv')
monmoy_bhai.to_csv('Monmoy_bhai_340:680.csv')
rakib.to_csv('rakib_680:~.csv')

# %%
x_test.to_csv('1000_instances_to_translate.csv')
